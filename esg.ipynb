# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("ESG-data.csv")

print("=== Preview the first and the last few rows ===")
print(df.head())
print(df.tail(7))
# Out:
# === Preview the first and the last few rows ===
#              company  country  revenue (mil)  carbon_emissions  \
# 0      TechCorp Inc.      USA           1500           55000.0
# 1  EcoSolutions Ltd.       UK             85            3000.0
# 2   GlobalBank Corp.      USA           5000               NaN
# 3    AutoMakers Inc.  Germany           2300          120000.0
# 4     SolarPower Co.    Spain             70            1500.0
#
#    waste_recycled  water_usage  emp_turnover_rate  diversity_board_pct  \
# 0          1200.0        80000               0.15                 0.30
# 1           850.0        15000               1.00                 0.50
# 2           500.0        70000               0.20                 0.25
# 3          2500.0       250000               0.08                 0.20
# 4           950.0        12000               0.05                 0.40
#
#    commu_invest  esg_score
# 0        500000       75.2
# 1        100000       92.1
# 2       1200000       68.9
# 3        800000       55.4
# 4         75000      111.1
#               company country  revenue (mil)  carbon_emissions  \
# 5    GlobalBank Corp.     USA           5500           85000.0
# 6     HealthCare Inc.   Japan           1200           25000.0
# 7      PharmaGroup SA  France           1800           35000.0
# 8    FashionTrend Co.   Italy            400           18000.0
# 9   EcoSolutions Ltd.      UK             80            2800.0
# 10      TechCorp Inc.     USA           1650           60000.0
# 11  EcoSolutions Ltd.      UK             80            2800.0
#
#     waste_recycled  water_usage  emp_turnover_rate  diversity_board_pct  \
# 5            700.0        75000               0.18                 0.25
# 6              NaN        45000               0.12                 0.35
# 7           1800.0        60000               0.14                 0.30
# 8            600.0        25000                NaN                 0.45
# 9            800.0        14500               0.11                 0.48
# 10          1350.0        85000               0.14                 0.32
# 11           800.0        14500               0.11                 0.48
#
#     commu_invest  esg_score
# 5        1500000       70.5
# 6         300000       82.3
# 7         450000       78.6
# 8         200000       60.1
# 9          95000       91.5
# 10        550000       77.8
# 11         95000       91.5

# %%
print("\n=== Size of data ===")
print(df.shape)

print("\n=== Basic structure of data ===")
print(df.info())

print("\n=== Basic statistics ===")
print(df.describe())

print("\n=== Column names ===")
print(df.columns)

# ---------------------------------------------------
# Quality Check
# ---------------------------------------------------

print("\n=== Missing Values ===")
print(df.isnull().sum())

print("\n=== Duplicate Records ===")
print(df.duplicated().sum())

print("\n=== Number of Unique Countries ===")
print(df['country'].nunique())
print(df['country'].value_counts())

print("\n=== Check esg_score > 90 ===")
print(df[df["esg_score"] > 90])

print("\n=== Boxplot of ESG Score ===")
sns.boxplot(x=df["esg_score"])
# Out:
# === Size of data ===
# (12, 10)
#
# === Basic structure of data ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              12 non-null     object
#  1   country              12 non-null     object
#  2   revenue (mil)        12 non-null     int64
#  3   carbon_emissions     11 non-null     float64
#  4   waste_recycled       11 non-null     float64
#  5   water_usage          12 non-null     int64
#  6   emp_turnover_rate    11 non-null     float64
#  7   diversity_board_pct  12 non-null     float64
#  8   commu_invest         12 non-null     int64
#  9   esg_score            12 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 1.1+ KB
# None
#
# === Basic statistics ===
#        revenue (mil)  carbon_emissions  waste_recycled    water_usage  \
# count      12.000000         11.000000       11.000000      12.000000
# mean     1638.750000      37100.000000     1095.454545   62166.666667
# std      1862.339834      39128.531789      596.428766   65583.511416
# min        70.000000       1500.000000      500.000000   12000.000000
# 25%        83.750000       2900.000000      750.000000   14875.000000
# 50%      1350.000000      25000.000000      850.000000   52500.000000
# 75%      1925.000000      57500.000000     1275.000000   76250.000000
# max      5500.000000     120000.000000     2500.000000  250000.000000
#
#        emp_turnover_rate  diversity_board_pct  commu_invest   esg_score
# count          11.000000            12.000000  1.200000e+01   12.000000
# mean            0.207273             0.356667  4.887500e+05   79.583333
# std             0.266274             0.102986  4.653597e+05   15.450203
# min             0.050000             0.200000  7.500000e+04   55.400000
# 25%             0.110000             0.287500  9.875000e+04   70.100000
# 50%             0.140000             0.335000  3.750000e+05   78.200000
# 75%             0.165000             0.457500  6.125000e+05   91.500000
# max             1.000000             0.500000  1.500000e+06  111.100000
#
# === Column names ===
# Index(['company', 'country', 'revenue (mil)', 'carbon_emissions',
#        'waste_recycled', 'water_usage', 'emp_turnover_rate',
#        'diversity_board_pct', 'commu_invest', 'esg_score'],
#       dtype='object')
#
# === Missing Values ===
# company                0
# country                0
# revenue (mil)          0
# carbon_emissions       1
# waste_recycled         1
# water_usage            0
# emp_turnover_rate      1
# diversity_board_pct    0
# commu_invest           0
# esg_score              0
# dtype: int64
#
# === Duplicate Records ===
# 1
#
# === Number of Unique Countries ===
# 7
# country
# USA        4
# UK         3
# Germany    1
# Spain      1
# Japan      1
# France     1
# Italy      1
# Name: count, dtype: int64
#
# === Check esg_score > 90 ===
#               company country  revenue (mil)  carbon_emissions  \
# 1   EcoSolutions Ltd.      UK             85            3000.0
# 4      SolarPower Co.   Spain             70            1500.0
# 9   EcoSolutions Ltd.      UK             80            2800.0
# 11  EcoSolutions Ltd.      UK             80            2800.0
#
#     waste_recycled  water_usage  emp_turnover_rate  diversity_board_pct  \
# 1            850.0        15000               1.00                 0.50
# 4            950.0        12000               0.05                 0.40
# 9            800.0        14500               0.11                 0.48
# 11           800.0        14500               0.11                 0.48
#
#     commu_invest  esg_score
# 1         100000       92.1
# 4          75000      111.1
# 9          95000       91.5
# 11         95000       91.5
#
# === Boxplot of ESG Score ===
# <Axes: xlabel='esg_score'>
